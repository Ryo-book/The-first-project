# %%
import numpy as np

# %%
rng = np.random.default_rng()

# %%
L = rng.random(100)
sum(L)
# Out:
# np.float64(51.41447638383764)

# %%
np.sum(L)
# Out:
# np.float64(51.414476383837666)

# %%
big_array = rng.random(1000000)
# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 51.8 ms ± 1.03 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 237 μs ± 6.49 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
min(big_array), max(big_array)
# Out:
# (np.float64(1.537729711120761e-06), np.float64(0.9999990367733766))

# %%
np.min(big_array), np.max(big_array)
# Out:
# (np.float64(1.537729711120761e-06), np.float64(0.9999990367733766))

# %%
# %timeit min(big_array)
# %timeit np.min(big_array)
# Out:
# 35.4 ms ± 243 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 138 μs ± 1.75 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
print(big_array.min(), big_array.max(), big_array.sum())
# Out:
# 1.537729711120761e-06 0.9999990367733766 500131.38225739426

# %%
M = rng.integers(0, 10, (3, 4))

# %%
print(M)
# Out:
# [[5 0 1 2]
#  [9 6 2 6]
#  [8 6 6 8]]

# %%
M.sum()
# Out:
# np.int64(59)

# %%
M.min(axis=0)
# Out:
# array([5, 0, 1, 2])

# %%
M.max(axis=1)
# Out:
# array([5, 9, 8])

# %%
# !head -4 data/president_heights.csv
# Out:
# 'head' �́A�����R�}���h�܂��͊O���R�}���h�A
# ����\�ȃv���O�����܂��̓o�b�` �t�@�C���Ƃ��ĔF������Ă��܂���B
