# %%
import pandas as pd

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=['a', 'b', 'c', 'd'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['b']
# Out:
# np.float64(0.5)

# %%
'a' in data
# Out:
# True

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
list(data.items())
# Out:
# [('a', 0.25), ('b', 0.5), ('c', 0.75), ('d', 1.0)]

# %%
data['e'] = 1.25
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# e    1.25
# dtype: float64

# %%
data['a':'c']
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64

# %%
data[0:2]
# Out:
# a    0.25
# b    0.50
# dtype: float64

# %%
data[(data > 0.3) & (data < 0.8)]
# Out:
# b    0.50
# c    0.75
# dtype: float64

# %%
data[['a', 'e']]
# Out:
# a    0.25
# e    1.25
# dtype: float64

# %%
#P115↓

# %%
import numpy as np

# %%
data = pd.Series(['a', 'b', 'c'], index=[1, 3, 5])
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
data[1]
# Out:
# 'a'

# %%
data[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %%
data.loc[1]
# Out:
# 'a'

# %%
data.loc[1:3]
# Out:
# 1    a
# 3    b
# dtype: object

# %%
data.iloc[1]
# Out:
# 'b'

# %%
data.iloc[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
                  'Florida': 170312, 'NewYork': 141297,
                  'Pensylvania': 119280})
pop = pd.Series({'California': 39538223, 'Texas': 29145505,
                  'Florida': 21538187, 'NewYork': 20201249,
                  'Pensylvania': 13002700})
data = pd.DataFrame({'area':area, 'pop': pop})

data
# Out:
#                area       pop
# California   423967  39538223
# Texas        695662  29145505
# Florida      170312  21538187
# NewYork      141297  20201249
# Pensylvania  119280  13002700

# %%
data['area']
# Out:
# California     423967
# Texas          695662
# Florida        170312
# NewYork        141297
# Pensylvania    119280
# Name: area, dtype: int64

# %%
data.area
# Out:
# California     423967
# Texas          695662
# Florida        170312
# NewYork        141297
# Pensylvania    119280
# Name: area, dtype: int64

# %%
data.pop is data['pop']
# Out:
# False

# %%
data['density'] = data['pop'] / data['area']

# %%
data
# Out:
#                area       pop     density
# California   423967  39538223   93.257784
# Texas        695662  29145505   41.896072
# Florida      170312  21538187  126.463121
# NewYork      141297  20201249  142.970120
# Pensylvania  119280  13002700  109.009893

# %%
data.values
# Out:
# array([[4.23967000e+05, 3.95382230e+07, 9.32577842e+01],
#        [6.95662000e+05, 2.91455050e+07, 4.18960717e+01],
#        [1.70312000e+05, 2.15381870e+07, 1.26463121e+02],
#        [1.41297000e+05, 2.02012490e+07, 1.42970120e+02],
#        [1.19280000e+05, 1.30027000e+07, 1.09009893e+02]])

# %%
data.T
# Out:
#            California         Texas       Florida       NewYork   Pensylvania
# area     4.239670e+05  6.956620e+05  1.703120e+05  1.412970e+05  1.192800e+05
# pop      3.953822e+07  2.914550e+07  2.153819e+07  2.020125e+07  1.300270e+07
# density  9.325778e+01  4.189607e+01  1.264631e+02  1.429701e+02  1.090099e+02

# %%
data.loc['Texas']
# Out:
# area       6.956620e+05
# pop        2.914550e+07
# density    4.189607e+01
# Name: Texas, dtype: float64

# %%
data.loc['Pensylvania']
# Out:
# area       1.192800e+05
# pop        1.300270e+07
# density    1.090099e+02
# Name: Pensylvania, dtype: float64

# %%
data.values[0]
# Out:
# array([4.23967000e+05, 3.95382230e+07, 9.32577842e+01])

# %%
data['area']
# Out:
# California     423967
# Texas          695662
# Florida        170312
# NewYork        141297
# Pensylvania    119280
# Name: area, dtype: int64

# %%
data.iloc[:3, :2]
# Out:
#               area       pop
# California  423967  39538223
# Texas       695662  29145505
# Florida     170312  21538187

# %%
data.loc[:'Florida', :'pop']
# Out:
#               area       pop
# California  423967  39538223
# Texas       695662  29145505
# Florida     170312  21538187

# %%
data.loc[data.density > 120, ['pop', 'density']]
# Out:
#               pop     density
# Florida  21538187  126.463121
# NewYork  20201249  142.970120

# %%
data.iloc[0, 2] = 90
data
# Out:
#                area       pop     density
# California   423967  39538223   90.000000
# Texas        695662  29145505   41.896072
# Florida      170312  21538187  126.463121
# NewYork      141297  20201249  142.970120
# Pensylvania  119280  13002700  109.009893

# %%
data['Florida': 'NewYork']
# Out:
#            area       pop     density
# Florida  170312  21538187  126.463121
# NewYork  141297  20201249  142.970120

# %%
data[1:3]
# Out:
#            area       pop     density
# Texas    695662  29145505   41.896072
# Florida  170312  21538187  126.463121

# %%
data[data.density > 120]
# Out:
#            area       pop     density
# Florida  170312  21538187  126.463121
# NewYork  141297  20201249  142.970120

# %%
data[data['pop'] > 20000000]
# Out:
#               area       pop     density
# California  423967  39538223   90.000000
# Texas       695662  29145505   41.896072
# Florida     170312  21538187  126.463121
# NewYork     141297  20201249  142.970120

# %%
data[data['area'] > 170000]
# Out:
#               area       pop     density
# California  423967  39538223   90.000000
# Texas       695662  29145505   41.896072
# Florida     170312  21538187  126.463121
