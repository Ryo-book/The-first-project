# %%
import pandas as pd
import numpy as np

# %%
valsl = np.array([1, None, 2, 3])
valsl
# Out:
# array([1, None, 2, 3], dtype=object)

# %%
# %timeit np.arange(1E6, dtype=int).sum()
# Out:
# 1.91 ms ± 17.7 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
valsl.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 valsl.sum()
#
# File c:\Users\Ryouh\miniconda3\Lib\site-packages\numpy\_core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
vals2 = np.array([1, np.nan, 3, 4])
vals2
# Out:
# array([ 1., nan,  3.,  4.])

# %%
1 + np.nan
# Out:
# nan

# %%
0 * np.nan
# Out:
# nan

# %%
vals2.sum(), vals2.min(), vals2.max()
# Out:
# (np.float64(nan), np.float64(nan), np.float64(nan))

# %%
np.isnan(vals2).all()
# Out:
# np.False_

# %%
np.nansum(vals2), np.nanmin(vals2), np.nanmax(vals2)
# Out:
# (np.float64(13.0), np.float64(1.0), np.float64(5.0))

# %%
pd.DataFrame(
    [
        [1, np.nan, 2, None],
             [1, np.nan, 2, None],
             [1, np.nan, 2, None],
             [1, np.nan, 2, None],
    ],
             index=['sapporo', 'tokyo', 'oosaka', 'okinawa'],
             columns=['0', '1', '2', '3']
)
# Out:
#          0   1  2     3
# sapporo  1 NaN  2  None
# tokyo    1 NaN  2  None
# oosaka   1 NaN  2  None
# okinawa  1 NaN  2  None

# %%
x = pd.Series(range(2), dtype=int)
x
# Out:
# 0    0
# 1    1
# dtype: int64

# %%
x[0] = None
x
# Out:
# 0    NaN
# 1    1.0
# dtype: float64

# %%
pd.Series([1, np.nan, 2, None, pd.NA], dtype='Int32')
# Out:
# 0       1
# 1    <NA>
# 2       2
# 3    <NA>
# 4    <NA>
# dtype: Int32

# %%
data = pd.Series([1, np.nan, 'hello', None])

# %%
data.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
data[data.notnull()]
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
data[data.isnull()]
# Out:
# 1     NaN
# 3    None
# dtype: object

# %%
data.dropna()
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
df = pd.DataFrame([[1,    np.nan, 2],
                [2,     3,     5],
                [np.nan, 4,    6]])
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df.dropna()
# Out:
#      0    1  2
# 1  2.0  3.0  5

# %%
df.dropna(axis=1)  #又は(axis='columns')
# Out:
#    2
# 0  2
# 1  5
# 2  6

# %%
df[3] = np.nan
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
df.dropna(axis='columns', how='all')
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df.dropna(axis='rows', thresh=3)
# Out:
#      0    1  2   3
# 1  2.0  3.0  5 NaN

# %%
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'),
                 dtype='Int32')
data
# Out:
# a       1
# b    <NA>
# c       2
# d    <NA>
# e       3
# dtype: Int32

# %%
data.fillna(0)
# Out:
# a    1
# b    0
# c    2
# d    0
# e    3
# dtype: Int32

# %%
data.fillna(method='ffill')
# Out:
# C:\Users\Ryouh\AppData\Local\Temp\ipykernel_18624\1844443866.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill')
# a    1
# b    1
# c    2
# d    2
# e    3
# dtype: Int32

# %%
data.fillna(method='bfill')
# Out:
# C:\Users\Ryouh\AppData\Local\Temp\ipykernel_18624\1397359497.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill')
# a    1
# b    2
# c    2
# d    3
# e    3
# dtype: Int32

# %%
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
df.fillna(method='ffill', axis=1)
# Out:
# C:\Users\Ryouh\AppData\Local\Temp\ipykernel_18624\901808322.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', axis=1)
#      0    1    2    3
# 0  1.0  1.0  2.0  2.0
# 1  2.0  3.0  5.0  5.0
# 2  NaN  4.0  6.0  6.0
